# %%
from ir_parser import get_ir_data

#红外测试-OUCAR文件
#特殊的INCAR写入：
"""
IBRION = 7
LEPSILON = .TRUE.
NWRITE = 3
"""
results = get_ir_data("/data2/home/luodh/Molecular/CO/freq")
print(results)
# Out:
# {'total_modes': 6, 'active_peaks': 1, 'max_frequency': 2243.3, 'peaks': [{'mode': 1, 'frequency': 2243.3, 'intensity': 1.0, 'is_imaginary': False}, {'mode': 2, 'frequency': 2.8, 'intensity': 0.0, 'is_imaginary': False}, {'mode': 3, 'frequency': 1.6, 'intensity': 0.0, 'is_imaginary': False}, {'mode': 4, 'frequency': 1.5, 'intensity': 0.0, 'is_imaginary': True}, {'mode': 5, 'frequency': 250.4, 'intensity': 0.001, 'is_imaginary': True}, {'mode': 6, 'frequency': 254.5, 'intensity': 0.002, 'is_imaginary': True}], 'source': '/data2/home/luodh/Molecular/CO/freq/OUTCAR'}

# %%
from xrd_parser import get_xrd_data

results = get_xrd_data("/data2/home/luodh/MetalOxide/spinel-Oxide/V2O4_Spinel/V2FeO4", radiation=1.01054)
print(results)
# Out:
# {'radiation': '1.01054', 'wavelength': 1.01054, 'formula': 'V2FeO4', 'spacegroup': 'P1', 'two_theta_range': [10.0, 90.0], 'total_peaks': 130, 'major_peaks': 21, 'max_peak': {'theta': 22.193, 'hkl': '2 1 1', 'intensity': 100.0}, 'peaks': [{'theta': 11.659, 'intensity': 9.164, 'hkl': '1 0 1', 'd_hkl': 4.9746, 'hkl_families': [{'hkl': '1 0 1', 'multiplicity': 8}]}, {'theta': 18.818, 'intensity': 18.874, 'hkl': '2 0 0', 'd_hkl': 3.0907, 'hkl_families': [{'hkl': '2 0 0', 'multiplicity': 4}]}, {'theta': 19.232, 'intensity': 34.402, 'hkl': '1 1 2', 'd_hkl': 3.0248, 'hkl_families': [{'hkl': '1 1 2', 'multiplicity': 8}]}, {'theta': 22.193, 'intensity': 100.0, 'hkl': '2 1 1', 'd_hkl': 2.6252, 'hkl_families': [{'hkl': '2 1 1', 'multiplicity': 16}]}, {'theta': 22.897, 'intensity': 52.746, 'hkl': '1 0 3', 'd_hkl': 2.5456, 'hkl_families': [{'hkl': '1 0 3', 'multiplicity': 8}]}, {'theta': 23.441, 'intensity': 7.298, 'hkl': '2 0 2', 'd_hkl': 2.4873, 'hkl_families': [{'hkl': '2 0 2', 'multiplicity': 
# ...

# %%
from nmr_parser import get_nmr_data

results = get_nmr_data("/data2/home/luodh/MetalOxide/spinel-Oxide/V2O4_Spinel/V2FeO4/nmr")
print(results)

results_efg = get_nmr_data("/data2/home/luodh/Test/VaspInput-Test/NMR-calc/nmr-calc_efg")
print(results_efg)
# Out:
# {'source': '/data2/home/luodh/MetalOxide/spinel-Oxide/V2O4_Spinel/V2FeO4/nmr/OUTCAR', 'n_ions': 14, 'has_cs': True, 'has_efg': False, 'chemical_shielding': {'n_ions': 14, 'core_contribution': {'O': -271.0767, 'Fe': -1932.8726, 'V': -1482.4641}, 'g0_contribution': [[-5.258593, 0.168683, -0.113859], [0.221229, -5.119217, -0.094654], [-0.07709, -0.115162, -4.961222], [-60.507509, 1.94094, -1.310114], [2.545553, -58.903794, -1.089129], [-0.88703, -1.325104, -57.085838], [2851.3451, 1836.191, 0.8117], [2827.0862, 1868.1243, 0.8098], [2853.8567, 1810.3126, 0.827], [2840.7831, 1756.9547, 0.8251], [1308.3021, 1046.4236, -0.8838], [1308.0165, 1049.9516, -0.8802], [145.2222, 180.0344, 0.504], [143.7641, 176.4793, 0.4063], [144.7749, 165.9542, 0.4085], [143.1269, 178.2508, 0.575], [145.3101, 165.1368, 0.4064], [142.7215, 178.4754, 0.5747], [145.4925, 179.3907, 0.5023], [144.1851, 176.3358, 0.4003], [1368.881, 1836.191, 0.8117], [1344.6221, 1868.1243, 0.8098], [1371.3926, 1810.3126, 0.827], [135
# ...
